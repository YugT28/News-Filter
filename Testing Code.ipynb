# %%
import os
# !pip install feedparser
# Out:
# ...
#   Obtaining dependency information for feedparser from https://files.pythonhosted.org/packages/7c/d4/8c31aad9cc18f451c49f7f9cfb5799dadffc88177f7917bc90a66459b1d7/feedparser-6.0.11-py3-none-any.whl.metadata
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/81.3 kB ? eta -:--:--
#    ----- ---------------------------------- 10.2/81.3 kB ? eta -:--:--
#    --------------- ------------------------ 30.7/81.3 kB 660.6 kB/s eta 0:00:01
#    ---------------------------------------- 81.3/81.3 kB 756.4 kB/s eta 0:00:00
# ...

# %%
# !python.exe -m pip install --upgrade pip
# Out:
# ...
#   Obtaining dependency information for pip from https://files.pythonhosted.org/packages/d4/55/90db48d85f7689ec6f81c0db0622d704306c5284850383c090e6c7195a5c/pip-24.2-py3-none-any.whl.metadata
#   Using cached pip-24.2-py3-none-any.whl.metadata (3.6 kB)
# Using cached pip-24.2-py3-none-any.whl (1.8 MB)
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 23.2.1
#     Uninstalling pip-23.2.1:
#       Successfully uninstalled pip-23.2.1
# ...

# %%
import feedparser
feed = feedparser.parse('http://rss.cnn.com/rss/cnn_topstories.rss')

# %%
len(feed)
# Out:
# 11

# %%
feed.popitem()
# Out:
# ('namespaces',
#  {'dc': 'http://purl.org/dc/elements/1.1/',
#   'content': 'http://purl.org/rss/1.0/modules/content/',
#   '': 'http://www.w3.org/2005/Atom',
#   'media': 'http://search.yahoo.com/mrss/'})

# %%
feed.popitem()
# Out:
# ('version', 'rss20')

# %%
feed.popitem()
# Out:
# ('encoding', 'utf-8')

# %%
feed.popitem()
# Out:
# ('status', 200)

# %%
feed.popitem()
# Out:
# ('href', 'http://rss.cnn.com/rss/cnn_topstories.rss')

# %%
feed.popitem()
# Out:
# ('updated_parsed',
#  time.struct_time(tm_year=2024, tm_mon=8, tm_mday=22, tm_hour=15, tm_min=19, tm_sec=24, tm_wday=3, tm_yday=235, tm_isdst=0))

# %%
feed.popitem()
# Out:
# ('updated', 'Thu, 22 Aug 2024 15:19:24 GMT')

# %%
feed.popitem()
# Out:
# ('headers',
#  {'content-type': 'text/xml; charset=utf-8',
#   'vary': 'Sec-Fetch-Dest, Sec-Fetch-Mode, Sec-Fetch-Site',
#   'feedburnerv2': '',
#   'last-modified': 'Thu, 22 Aug 2024 15:19:24 GMT',
#   'cache-control': 'no-cache, no-store, max-age=0, must-revalidate',
#   'pragma': 'no-cache',
#   'expires': 'Mon, 01 Jan 1990 00:00:00 GMT',
#   'date': 'Tue, 08 Oct 2024 05:46:30 GMT',
#   'content-security-policy': "require-trusted-types-for 'script';report-uri /_/RaichuFeedServer/cspreport",
#   'accept-ch': 'Sec-CH-UA-Arch, Sec-CH-UA-Bitness, Sec-CH-UA-Full-Version, Sec-CH-UA-Full-Version-List, Sec-CH-UA-Model, Sec-CH-UA-WoW64, Sec-CH-UA-Form-Factors, Sec-CH-UA-Platform, Sec-CH-UA-Platform-Version',
#   'cross-origin-opener-policy': 'same-origin',
#   'cross-origin-resource-policy': 'same-site',
# ...

# %%
feed.popitem()
# Out:
# ('feed',
#  {'title': 'CNN.com - RSS Channel - HP Hero',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://rss.cnn.com/rss/cnn_topstories.rss',
#    'value': 'CNN.com - RSS Channel - HP Hero'},
#   'subtitle': 'CNN.com delivers up-to-the-minute news and information on the latest top stories, weather, entertainment, politics and more.',
#   'subtitle_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://rss.cnn.com/rss/cnn_topstories.rss',
#    'value': 'CNN.com delivers up-to-the-minute news and information on the latest top stories, weather, entertainment, politics and more.'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://www.cnn.com/index.html'}],
#   'link': 'https://www.cnn.com/index.html',
#   'image': {'href': 'http://i2.cdn.turner.com/cnn/2015/images/09/24/cnn.digital.png',
#    'title': 'CNN.com - RSS Channel - HP Hero',
#    'title_detail': {'type': 'text/plain',
# ...

# %%
feed.popitem()
# Out:
# ('entries',
#  [{'title': 'Some on-air claims about Dominion Voting Systems were false, Fox News acknowledges in statement after deal is announced',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://rss.cnn.com/rss/cnn_topstories.rss',
#     'value': 'Some on-air claims about Dominion Voting Systems were false, Fox News acknowledges in statement after deal is announced'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.cnn.com/business/live-news/fox-news-dominion-trial-04-18-23/index.html'}],
#    'link': 'https://www.cnn.com/business/live-news/fox-news-dominion-trial-04-18-23/index.html',
#    'id': 'https://www.cnn.com/business/live-news/fox-news-dominion-trial-04-18-23/index.html',
#    'guidislink': False,
#    'published': 'Wed, 19 Apr 2023 12:44:51 GMT',
# ...

# %%
feed.popitem()
# Out:
# ('bozo', False)

# %%
feed.popitem()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 feed.popitem()
#
# KeyError: 'popitem(): dictionary is empty'

# %% [markdown]
# # Again Reloading Feed

# %%
feed = feedparser.parse('http://rss.cnn.com/rss/cnn_topstories.rss')

# %%
feed['entries'].__len__()
# Out:
# 69

# %%
type(feed['entries'])
# Out:
# list

# %%
feed['entries'][0]
# Out:
# {'title': 'Some on-air claims about Dominion Voting Systems were false, Fox News acknowledges in statement after deal is announced',
#  'title_detail': {'type': 'text/plain',
#   'language': None,
#   'base': 'http://rss.cnn.com/rss/cnn_topstories.rss',
#   'value': 'Some on-air claims about Dominion Voting Systems were false, Fox News acknowledges in statement after deal is announced'},
#  'links': [{'rel': 'alternate',
#    'type': 'text/html',
#    'href': 'https://www.cnn.com/business/live-news/fox-news-dominion-trial-04-18-23/index.html'}],
#  'link': 'https://www.cnn.com/business/live-news/fox-news-dominion-trial-04-18-23/index.html',
#  'id': 'https://www.cnn.com/business/live-news/fox-news-dominion-trial-04-18-23/index.html',
#  'guidislink': False,
#  'published': 'Wed, 19 Apr 2023 12:44:51 GMT',
#  'published_parsed': time.struct_time(tm_year=2023, tm_mon=4, tm_mday=19, tm_hour=12, tm_min=44, tm_sec=51, tm_wday=2, tm_yday=109, tm_isdst=0),
# ...

# %%
type(feed['entries'][0])
# Out:
# feedparser.util.FeedParserDict

# %%
for entry in feed['entries']:
    print(entry.keys())
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'id', 'guidislink', 'published', 'published_parsed', 'media_content'])
# dict_keys(['title', 'title_detail', 'links', 'link', 'id', 'guidislink', 'media_content'])
# dict_keys(['title', 'title_detail', 'summary', 'summary_detail', 'links', 'link', 'id', 'guidislink', 'published', 'published_parsed', 'media_content'])
# dict_keys(['title', 'title_detail', 'summary', 'summary_detail', 'links', 'link', 'id', 'guidislink', 'published', 'published_parsed', 'media_content'])
# dict_keys(['title', 'title_detail', 'summary', 'summary_detail', 'links', 'link', 'id', 'guidislink', 'published', 'published_parsed', 'media_content'])
# dict_keys(['title', 'title_detail', 'summary', 'summary_detail', 'links', 'link', 'id', 'guidislink', 'published', 'published_parsed', 'media_content'])
# dict_keys(['title', 'title_detail', 'summary', 'summary_detail', 'links', 'link', 'id', 'guidislink', 'published', 'published_parsed', 'media_content'])
# ...

# %%
feed['entries'][68]
# Out:
# {'title': "Review: 'Barry' takes a whack at its farewell season",
#  'title_detail': {'type': 'text/plain',
#   'language': None,
#   'base': 'http://rss.cnn.com/rss/cnn_topstories.rss',
#   'value': "Review: 'Barry' takes a whack at its farewell season"},
#  'summary': '"Barry" has taken chances from the very beginning, which is certainly true of a fourth and final season that picks up where the third left off, with its hitman-turned-wannabe actor getting arrested. That paves the way for an even darker season that accentuates the show\'s ensemble aspect while leaning a little too heavily on blurring lines with flights of fancy.',
#  'summary_detail': {'type': 'text/html',
#   'language': None,
#   'base': 'http://rss.cnn.com/rss/cnn_topstories.rss',
# ...

# %%
feed['entries'][0]
# Out:
# {'title': 'Some on-air claims about Dominion Voting Systems were false, Fox News acknowledges in statement after deal is announced',
#  'title_detail': {'type': 'text/plain',
#   'language': None,
#   'base': 'http://rss.cnn.com/rss/cnn_topstories.rss',
#   'value': 'Some on-air claims about Dominion Voting Systems were false, Fox News acknowledges in statement after deal is announced'},
#  'links': [{'rel': 'alternate',
#    'type': 'text/html',
#    'href': 'https://www.cnn.com/business/live-news/fox-news-dominion-trial-04-18-23/index.html'}],
#  'link': 'https://www.cnn.com/business/live-news/fox-news-dominion-trial-04-18-23/index.html',
#  'id': 'https://www.cnn.com/business/live-news/fox-news-dominion-trial-04-18-23/index.html',
#  'guidislink': False,
#  'published': 'Wed, 19 Apr 2023 12:44:51 GMT',
#  'published_parsed': time.struct_time(tm_year=2023, tm_mon=4, tm_mday=19, tm_hour=12, tm_min=44, tm_sec=51, tm_wday=2, tm_yday=109, tm_isdst=0),
# ...

# %% [markdown]
# # Taking another URL and Loking into it

# %% [markdown]
# #### qz.com/

# %%
feed=feedparser.parse(r"http://qz.com/feed")

# %%
type(feed)
# Out:
# feedparser.util.FeedParserDict

# %%
feed.keys()
# Out:
# dict_keys(['bozo', 'entries', 'feed', 'headers', 'etag', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %%
feed['bozo']
# Out:
# False

# %%
feed['entries']
# Out:
# [{'title': "Costco's gold bars are selling out fast as shoppers eye financial security",
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://qz.com/rss',
#    'value': "Costco's gold bars are selling out fast as shoppers eye financial security"},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://qz.com/costco-gold-bars-metal-silver-platinum-retail-consumer-1851667327'}],
#   'link': 'https://qz.com/costco-gold-bars-metal-silver-platinum-retail-consumer-1851667327',
# ...

# %%
type(feed['entries'])
# Out:
# list

# %%
feed['entries'][0]
# Out:
# {'title': "Costco's gold bars are selling out fast as shoppers eye financial security",
#  'title_detail': {'type': 'text/plain',
#   'language': None,
#   'base': 'https://qz.com/rss',
#   'value': "Costco's gold bars are selling out fast as shoppers eye financial security"},
#  'links': [{'rel': 'alternate',
#    'type': 'text/html',
#    'href': 'https://qz.com/costco-gold-bars-metal-silver-platinum-retail-consumer-1851667327'}],
#  'link': 'https://qz.com/costco-gold-bars-metal-silver-platinum-retail-consumer-1851667327',
# ...

# %%
feed['entries'][1]
# Out:
# {'title': 'FTX shareholders could get $1 billion after crypto firm is cleared to fully repay customers',
#  'title_detail': {'type': 'text/plain',
#   'language': None,
#   'base': 'https://qz.com/rss',
#   'value': 'FTX shareholders could get $1 billion after crypto firm is cleared to fully repay customers'},
#  'links': [{'rel': 'alternate',
#    'type': 'text/html',
#    'href': 'https://qz.com/ftx-shareholders-billion-seized-crypto-exchange-sbf-1851667188'}],
#  'link': 'https://qz.com/ftx-shareholders-billion-seized-crypto-exchange-sbf-1851667188',
#  'summary': '<img class="type:primaryImage" src="https://i.kinja-img.com/image/upload/c_fit,q_80,w_636/a0da3871c4dbf126245cc0ae4a47b7bd.jpg" /><p>A judge has reportedly approved payments to customers of collapsed crypto exchange FTX — and its shareholders could get $1 billion in seized assets. </p><p><a href="https://qz.com/ftx-shareholders-billion-seized-crypto-exchange-sbf-1851667188">Read more...</a></p>',
# ...

# %%
for i in feed['entries']:
    print(i.keys())
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'summary', 'summary_detail', 'tags', 'published', 'published_parsed', 'id', 'guidislink', 'authors', 'author', 'author_detail', 'media_thumbnail', 'href'])
# dict_keys(['title', 'title_detail', 'links', 'link', 'summary', 'summary_detail', 'tags', 'published', 'published_parsed', 'id', 'guidislink', 'authors', 'author', 'author_detail', 'media_thumbnail', 'href'])
# dict_keys(['title', 'title_detail', 'links', 'link', 'summary', 'summary_detail', 'tags', 'published', 'published_parsed', 'id', 'guidislink', 'authors', 'author', 'author_detail', 'media_thumbnail', 'href'])
# dict_keys(['title', 'title_detail', 'links', 'link', 'summary', 'summary_detail', 'tags', 'published', 'published_parsed', 'id', 'guidislink', 'authors', 'author', 'author_detail', 'media_thumbnail', 'href'])
# ...

# %%
# !pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
# Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.6 MB 1.9 MB/s eta 0:00:07
#    -- ------------------------------------- 0.8/12.6 MB 1.2 MB/s eta 0:00:10
#    -- ------------------------------------- 0.8/12.6 MB 1.2 MB/s eta 0:00:10
#    --- ------------------------------------ 1.0/12.6 MB 1.1 MB/s eta 0:00:11
#    ---- ----------------------------------- 1.3/12.6 MB 1.0 MB/s eta 0:00:11
#    ----- ---------------------------------- 1.6/12.6 MB 1.0 MB/s eta 0:00:11
#    ----- ---------------------------------- 1.8/12.6 MB 1.0 MB/s eta 0:00:11
#    ----- ---------------------------------- 1.8/12.6 MB 1.0 MB/s eta 0:00:11
# ...

# %%
feed['namespaces']
# Out:
# {'dc': 'http://purl.org/dc/elements/1.1/',
#  'content': 'http://purl.org/rss/1.0/modules/content/',
#  'media': 'http://search.yahoo.com/mrss/',
#  '': 'http://www.w3.org/2005/Atom'}

# %%
feed.keys()
# Out:
# dict_keys(['bozo', 'entries', 'feed', 'headers', 'etag', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %%
feed['href']
# Out:
# 'https://qz.com/rss'

# %%
feed['headers']
# Out:
# {'connection': 'close',
#  'content-length': '20766',
#  'x-powered-by': 'Express',
#  'x-kinja': 'kinja-magma-kube01-5f4f46769b-fjjln #5235',
#  'x-kinja-revision': 'e6903cc5216217643a77fe931d26ec312afc0959',
#  'x-kinja-server': 'kinja-magma-kube01-5f4f46769b-fjjln',
#  'x-kinja-build': '5235',
#  'cache-control': 'stale-if-error=86400, stale-while-revalidate=300',
#  'content-security-policy': "frame-ancestors 'self'; upgrade-insecure-requests",
#  'x-content-type-options': 'nosniff',
#  'x-xss-protection': '1; mode=block',
#  'strict-transport-security': 'max-age=63072000; includeSubDomains; preload',
#  'x-googlenews-bot': 'false',
#  'content-type': 'application/xml; charset=utf-8',
#  'etag': 'W/"19167-ADaR83e/naUME2E4k6FBAr8TjRQ"',
#  'content-encoding': 'gzip',
#  'via': '1.1 varnish, 1.1 varnish',
#  'x-cdn-fetch': 'mantle-default',
#  'accept-ranges': 'bytes',
#  'date': 'Tue, 08 Oct 2024 06:54:04 GMT',
#  'age': '27',
# ...

# %%
feed['feed']
# Out:
# {'title': 'Quartz',
#  'title_detail': {'type': 'text/plain',
#   'language': None,
#   'base': 'https://qz.com/rss',
#   'value': 'Quartz'},
#  'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://qz.com'},
#   {'href': 'https://qz.com', 'rel': 'self', 'type': 'application/rss+xml'}],
#  'link': 'https://qz.com',
#  'subtitle': 'Kinja RSS',
#  'subtitle_detail': {'type': 'text/html',
#   'language': None,
#   'base': 'https://qz.com/rss',
#   'value': 'Kinja RSS'},
#  'language': 'en'}

# %%
feed['etag']
# Out:
# 'W/"19167-ADaR83e/naUME2E4k6FBAr8TjRQ"'

# %%
import pandas as pd
df=pd.read_csv("data/List_of_RSS.csv",header=None)

# %%
def bozo_status(row):
    status=feedparser.parse(row)['bozo']
    return status
    
df[0].apply(bozo_status)
# Out:
# ---------------------------------------------------------------------------
# ConnectionAbortedError                    Traceback (most recent call last)
# Cell In[200], line 5
#       2     status=feedparser.parse(row)['bozo']
#       3     return status
# ----> 5 df[0].apply(bozo_status)
#
# File ~\PycharmProjects\News Filter\.venv\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# ...

# %%
for i in df[0]:
    feed=feedparser.parse(i)
    if feed.get('bozo_exception',False):
        pass
    else:
        print("{}->{}".format(i,feed['bozo']))
        # print(feed.keys())
        print(feed['entries'][0].keys())
# Out:
# http://rss.cnn.com/rss/cnn_topstories.rss->False
# dict_keys(['title', 'title_detail', 'links', 'link', 'id', 'guidislink', 'published', 'published_parsed', 'media_content'])
# http://qz.com/feed->False
# dict_keys(['title', 'title_detail', 'links', 'link', 'summary', 'summary_detail', 'tags', 'published', 'published_parsed', 'id', 'guidislink', 'authors', 'author', 'author_detail', 'media_thumbnail', 'href'])
# http://feeds.foxnews.com/foxnews/politics->False
# dict_keys(['links', 'link', 'id', 'guidislink', 'title', 'title_detail', 'summary', 'summary_detail', 'content', 'media_content', 'tags', 'published', 'published_parsed'])
# http://feeds.feedburner.com/NewshourWorld->False
# dict_keys(['title', 'title_detail', 'links', 'link', 'comments', 'published', 'published_parsed', 'authors', 'author', 'author_detail', 'tags', 'id', 'guidislink', 'summary', 'summary_detail', 'content', 'wfw_commentrss', 'slash_comments', 'itunes_duration', 'media_content'])
# ...

# %%
#entity Related Terms

# %% [markdown]
# # ************************

# %%
li=['tags','title','summary','href','link','author']
for z in df[0]:
    feed=feedparser.parse(z)
    for i in feed['entries']:
        for j in li:
            print("{}->{}".format(j,i.get(j,False)))
    print("*"*10,z,"*"*10)
# Out:
# tags->False
# title->Some on-air claims about Dominion Voting Systems were false, Fox News acknowledges in statement after deal is announced
# summary->False
# href->False
# link->https://www.cnn.com/business/live-news/fox-news-dominion-trial-04-18-23/index.html
# author->False
# tags->False
# title->Dominion still has pending lawsuits against election deniers such as Rudy Giuliani and Sidney Powell
# summary->False
# href->False
# link->https://www.cnn.com/business/live-news/fox-news-dominion-trial-04-18-23/h_8d51e3ae2714edaa0dace837305d03b8
# author->False
# tags->False
# title->Here are the 20 specific Fox broadcasts and tweets Dominion says were defamatory
# summary->• Fox-Dominion trial delay 'is not unusual,' judge says
# • Fox News' defamation battle isn't stopping Trump's election lies
# href->False
# link->https://www.cnn.com/2023/04/17/media/dominion-fox-news-allegations/index.html
# author->False
# tags->False
# ...

# %% [markdown]
# # *********************

# %%
feed=feedparser.parse(r"http://rss.cnn.com/rss/cnn_topstories.rss")

# %%
feed['entries'][0]
# Out:
# {'title': 'Some on-air claims about Dominion Voting Systems were false, Fox News acknowledges in statement after deal is announced',
#  'title_detail': {'type': 'text/plain',
#   'language': None,
#   'base': 'http://rss.cnn.com/rss/cnn_topstories.rss',
#   'value': 'Some on-air claims about Dominion Voting Systems were false, Fox News acknowledges in statement after deal is announced'},
#  'links': [{'rel': 'alternate',
#    'type': 'text/html',
#    'href': 'https://www.cnn.com/business/live-news/fox-news-dominion-trial-04-18-23/index.html'}],
#  'link': 'https://www.cnn.com/business/live-news/fox-news-dominion-trial-04-18-23/index.html',
#  'id': 'https://www.cnn.com/business/live-news/fox-news-dominion-trial-04-18-23/index.html',
#  'guidislink': False,
#  'published': 'Wed, 19 Apr 2023 12:44:51 GMT',
#  'published_parsed': time.struct_time(tm_year=2023, tm_mon=4, tm_mday=19, tm_hour=12, tm_min=44, tm_sec=51, tm_wday=2, tm_yday=109, tm_isdst=0),
# ...

# %%
feed['entries'][0]
# Out:
# '<p><strong>HARI SREENIVASAN:</strong> President Xi Jinping opened China&#8217;s twice-per-decade Communist Party Congress today with a lengthy list of his achievements during his first five-year term, and his vision of where he hopes to take his nation.</p>\n<p>But beyond the words, Xi is asserting power like no Chinese leader in decades.</p>\n<p>William Brangham reports.</p>\n<p><strong>WILLIAM BRANGHAM:</strong> The applause, the music, it was a reception befitting the commanding role that Xi Jinping has taken since being named party leader five years ago.</p>\n<p>He opened today&#8217;s proceedings by hailing reforms he&#8217;s put in place, and proclaiming a &#8212; quote &#8212; &#8220;new era for China.&#8221;</p>\n<p><strong>PRESIDENT XI JINPING,</strong> China (through interpreter): The Chinese nation has realized a great leap, from declining in modern history to twisting its fate fundamentally and continuously moving to prosperity.</p>\n<p><strong>WILLIAM BRANGHAM:</strong>
# ...

# %%
feedparser.parse(r'http://qz.com/feed')
# Out:
# {'bozo': False,
#  'entries': [{'title': "Costco's gold bars are selling out fast as shoppers eye financial security",
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://qz.com/rss',
#     'value': "Costco's gold bars are selling out fast as shoppers eye financial security"},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://qz.com/costco-gold-bars-metal-silver-platinum-retail-consumer-1851667327'}],
#    'link': 'https://qz.com/costco-gold-bars-metal-silver-platinum-retail-consumer-1851667327',
# ...

# %%
feedparser.parse(r'http://feeds.reuters.com/reuters/businessNews')
# Out:
# {'bozo': True,
#  'entries': [],
#  'feed': {},
#  'headers': {},
#  'bozo_exception': urllib.error.URLError(socket.gaierror(11001,
#                                        'getaddrinfo failed'))}

# %%
feed
# Out:
# {'bozo': True,
#  'entries': [],
#  'feed': {},
#  'headers': {},
#  'bozo_exception': urllib.error.URLError(socket.gaierror(11001,
#                                        'getaddrinfo failed'))}

# %%
# !pip install SQLAlchemy
# Out:
# ...
#   Using cached SQLAlchemy-2.0.35-cp312-cp312-win_amd64.whl.metadata (9.9 kB)
# ...
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached greenlet-3.1.1-cp312-cp312-win_amd64.whl.metadata (3.9 kB)
# Using cached SQLAlchemy-2.0.35-cp312-cp312-win_amd64.whl (2.1 MB)
# Using cached greenlet-3.1.1-cp312-cp312-win_amd64.whl (299 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# ...

# %%
import sqlalchemy

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///:memory:',echo=True)

# %%
from sqlalchemy import text
with engine.connect() as conn:
    result=conn.execute(text("select * from news"))
# Out:
# 2024-10-08 16:33:33,491 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-08 16:33:33,495 INFO sqlalchemy.engine.Engine select * from news
# 2024-10-08 16:33:33,495 INFO sqlalchemy.engine.Engine [generated in 0.00410s] ()
# 2024-10-08 16:33:33,498 INFO sqlalchemy.engine.Engine ROLLBACK
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\PycharmProjects\News Filter\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# ...

# %%
result.mappings()

# %%
# can send parameter in execute {}
[{"x": 11, "y": 12}, {"x": 13, "y": 14}],

conn.commit()

# %%
# orm session

# %% [markdown]
# # ******************************

# %%
engine = create_engine('mysql://root:root@localhost:3306/news')

# %%
#setting MEta data of table
from sqlalchemy.orm import DeclarativeBase
from sqlalchemy import create_engine,Column, String, Text, URL
from sqlalchemy.ext.declarative import declarative_base

class Base(DeclarativeBase):
    pass

class News(Base):
    __tablename__ = 'article'
    link=Column(String(50), primary_key=True)
    title=Column(Text)

Base.metadata.create_all(engine)

# %%
from sqlalchemy.orm import Session
session=Session(engine)
session.add(News(link="abc",title="Nano"))
session.commit()

# %%
# !pip install mysql-connector-python
# Out:
# ...
#    ---------------------------------------- 0.0/14.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/14.3 MB 3.7 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.6/14.3 MB 3.5 MB/s eta 0:00:04
#    ------- -------------------------------- 2.6/14.3 MB 4.0 MB/s eta 0:00:03
#    --------- ------------------------------ 3.4/14.3 MB 4.2 MB/s eta 0:00:03
#    ------------- -------------------------- 4.7/14.3 MB 4.5 MB/s eta 0:00:03
#    ---------------- ----------------------- 5.8/14.3 MB 4.5 MB/s eta 0:00:02
#    -------------------- ------------------- 7.3/14.3 MB 4.9 MB/s eta 0:00:02
#    ------------------------ --------------- 8.9/14.3 MB 5.2 MB/s eta 0:00:02
#    --------------------------- ------------ 10.0/14.3 MB 5.1 MB/s eta 0:00:01
#    -------------------------------- ------- 11.5/14.3 MB 5.3 MB/s eta 0:00:01
# ...

# %%
# !pip install mysqlclient

# %% [markdown]
# # ******************************

# %%
from pathlib import Path

# %%
#making news Directory
news=Path.cwd().joinpath(Path('news'))
news.mkdir(exist_ok=True)

# %%
#making subdirectory like component constant entity exception logger pipeline utils 
component=news.joinpath(Path('component'))
component.mkdir(exist_ok=True)

constant=news.joinpath(Path('constant'))
constant.mkdir(exist_ok=True)

entity=news.joinpath(Path('entity'))
entity.mkdir(exist_ok=True)

exception=news.joinpath(Path('exception'))
exception.mkdir(exist_ok=True)

logger=news.joinpath(Path('logger'))
logger.mkdir(exist_ok=True)

pipeline=news.joinpath(Path('pipeline'))
pipeline.mkdir(exist_ok=True)

utils=news.joinpath(Path('utils'))
utils.mkdir(exist_ok=True)

# %%
x=news/"__init__.py"
x.touch()

x=component/"__init__.py"
x.touch()

# %%
requirements=Path.cwd()/'requirements.txt'
requirements.touch()

# %%
setup=Path.cwd()/"setup.py"
setup.touch()

# %%
from news.logger import logger

# %%
from news.entity import artifact

# %%
from dotenv import load_dotenv
import os
load_dotenv()
os.getenv('MYSQL_CONNECTION_STRING')
# Out:
# 'mysql://root:root@localhost:3306/news'

# %%
from bs4 import BeautifulSoup
import requests

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Mobile Safari/537.36 Edg/129.0.0.0',
    'Accept-Language': 'en-US,en;q=0.9,en-IN;q=0.8',
    'Accept-Encoding': 'gzip, deflate, br, zstd',
    'Connection': 'keep-alive',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'Referer': 'https://www.newsnow.co.uk/',
    'Upgrade-Insecure-Requests':'1',
    'sec-ch-ua': "Microsoft Edge",
    'priority':'u=1,i'
    
}

# %%
html=requests.get('https://www.newsnow.co.uk/h/World+News/Natural+Disasters')
soup=BeautifulSoup(html.text)
for i in soup.find_all('div',class_='hl__inner'):
    print(i.find('a').text)
# Out:
# Flood alerts and warnings: Heavy rain sees dozens of Environment Agency alerts issued in UK -…
# Flood warnings remain in place across the West Country
# Heightened alerts for rain, wind, and flooding as hurricane Kirk arrives in France
# How long will hurricane Kirk (now officially a strong storm) batter France?
# Two elephants die in flooding at sanctuary in northern Thailand
# Two elephants die in Thailand flooding
# 2nd person dies in western North Dakota wildfires
# Western North Dakota wildfire claims second victim
# Moderate mag. 4.3 earthquake - North Pacific Ocean, 65 km southwest of Tapachula de Cordova y Ordoñez, Mexico, on…
# Moderate mag. 4.0 earthquake - North Pacific Ocean, 132 km southwest of Tapachula de Cordova y Ordoñez, Mexico, on…
# Gunter: Federal negligence at root of Jasper's wildfire devastation
# Jasper wildfire: Alberta minister urges improved unified command structure
# Millions evacuate as Hurricane Milton threatens Tampa Bay with 15-foot surge
# ...

# %%
html1=requests.get('https://www.newsnow.co.uk/h/World+News/Natural+Disasters?type=ln',headers=headers)
soup1=BeautifulSoup(html.text)
j=0
for i in soup1.find_all('a',class_='hll'):
    print(i.text)
    j+=1
print(j)
# Out:
# Flood alerts and warnings: Heavy rain sees dozens of Environment Agency alerts issued in UK -…
# Flood warnings remain in place across the West Country
# Heightened alerts for rain, wind, and flooding as hurricane Kirk arrives in France
# How long will hurricane Kirk (now officially a strong storm) batter France?
# Two elephants die in flooding at sanctuary in northern Thailand
# Two elephants die in Thailand flooding
# 2nd person dies in western North Dakota wildfires
# Western North Dakota wildfire claims second victim
# Moderate mag. 4.3 earthquake - North Pacific Ocean, 65 km southwest of Tapachula de Cordova y Ordoñez, Mexico, on…
# Moderate mag. 4.0 earthquake - North Pacific Ocean, 132 km southwest of Tapachula de Cordova y Ordoñez, Mexico, on…
# Gunter: Federal negligence at root of Jasper's wildfire devastation
# Jasper wildfire: Alberta minister urges improved unified command structure
# Millions evacuate as Hurricane Milton threatens Tampa Bay with 15-foot surge
# ...

# %%
#RSS

# %%
import pandas as pd
import feedparser
import numpy as np

# %%
def rss_extract(url)->pd.DataFrame:
    li=['title','link','summary','author','tags']
    urls=[url]
    model_building_article=pd.DataFrame(columns=li)
    for z in urls:
        feed=feedparser.parse(z)
        for i in feed['entries']:
            data={}
            for j in li:
                data[j]=i.get(j,np.nan)
            model_building_article=model_building_article._append(data,ignore_index=True)
    return model_building_article

# %%
#natural-disaster
rss_extract("https://www.theguardian.com/environment/climate-crisis/rss")
# Out:
#                                                 title  \
# 0   Hurricane Milton: what does it actually take t...
# 1   Hurricanes like Helene twice as likely to happ...
# 2   China to head green energy boom with 60% of ne...
# 3   Energy industry trade body chief to head UK’s ...
# 4   US south-east reels from ‘unspeakable tragedy’...
# 5   Double punch of hurricanes could become common...
# 6   Oregon county sues major gas provider for alle...
# 7   Earth’s ‘vital signs’ show humanity’s future i...
# 8   Deforestation ‘roaring back’ despite 140-count...
# 9   Chris Boardman urges Premier League clubs to s...
# 10  Hurricane Helene is a humanitarian crisis – an...
# 11  Today, with a £22bn pledge for carbon capture,...
# 12  Plibersek’s coalmine decision is double troubl...
# 13  As the waters rise, a two-year sentence for th...
# 14  Amid Australia’s chaotic climate politics, the...
# 15  ‘A huge loss’: is it the end for the ship that...
# ...

# %%
#protest
rss_extract('https://www.theguardian.com/world/protest/rss')
# Out:
#                                                 title  \
# 0   Australia reviews pro-Palestine activist’s vis...
# 1   ‘Democracy should not be monetised’: unions re...
# 2   Environment summit taking place in Sydney whil...
# 3   NSW premier says police should be able to ban ...
# 4   Protesters rally across the US on 7 October an...
# 5   Protesters for Palestine and Israel rally acro...
# 6   Australian politicians mark 7 October annivers...
# 7   Albanese acknowledges ‘terrible pain’ of Hamas...
# 8     How England’s far-right riots erupted - podcast
# 9   A year of horror, vile political point-scoring...
# 10  US universities failed to nurture meaningful d...
# 11  Pro-Palestine rallies across Australia – in pi...
# 12  ‘We just want peace’: anger and grief as thous...
# 13  Tens of thousands join pro-Palestinian protest...
# 14  How Gaza sparked the biggest UK protest moveme...
# 15  Thousands of pro-Palestinian protesters march ...
# ...

# %%
#politics
rss_extract("https://rss.nytimes.com/services/xml/rss/nyt/Politics.xml")
# Out:
#                                                 title  \
# 0   13 Things We Learned From Harris’s Interview W...
# 1   Small Business Administration Will Soon Exhaus...
# 2   Iran Crisis Ignites New Debate About Trump’s N...
# 3   Inside a Harris Ad in Which Ex-Trump Aides Bla...
# 4   Months Before Ethiopian Crash, Boeing Turned A...
# 5   Trump Holds Up Transition Process, Skirting Et...
# 6   Inside the Battle for America’s Most Consequen...
# 7    Trump Family Business Eyes Hotel Deals in Israel
# 8   Tim Walz Calls for Abolishing the Electoral Co...
# 9   Harris Cracks a Beer With Colbert and Talks Ga...
# 10  Afghan Man Charged With Plotting Election Day ...
# 11  What Will Happen If Trump Wins the 2024 Election?
# 12  With Kennedy on the Ballot, Vance Talks Public...
# 13  Romney Won’t Endorse Harris, Saying He Wants t...
# 14  Yoav Gallant, Israel’s Defense Minister, Postp...
# 15  Biden Excoriated Netanyahu on Israel’s Conduct...
# ...

# %%
#terrorism
rss_extract("https://www.theguardian.com/politics/terrorism/rss")
# Out:
#                                                 title  \
# 0   Tugendhat condemns Tory rival over claim UK sp...
# 1   Martyn’s law to require terror safety plans at...
# 2   Can the UK fight ‘extreme misogyny’ as if it w...
# 3   Yvette Cooper vows to crack down on promotion ...
# 4   UK riots expose double standards on far-right ...
# 5   ‘Two-tier’: UK treats far-right attacks less h...
# 6   Immigration lawyers ‘at risk’ amid far-right t...
# 7   Worst far-right violence should be treated as ...
# 8   Conservatives left UK wide open to far-right v...
# 9   Labour unlikely to rush into proscribing Iran’...
# 10  Lost laws: which legislation will slip through...
# 11  Met police to pay ‘five-figure sum’ to French ...
# 12  Does Counter-Terrorism Work? by Richard Englis...
# 13  Ironies abound in Michael Gove’s definition of...
# 14  More young people being radicalised online, sa...
# 15  Michael Gove’s definition of extremism will sh...
# ...

# %%
#positive
positive_category=["Society",
'Environment',
'Lifestyle',
'Science',
'Economics',
'Opinion',
'UK',
'World',
'Partners']
positive=pd.DataFrame(columns=li)
for i in positive_category:
    df_positive=rss_extract(f"https://www.positive.news/category/{i}/feed/")
    positive=positive._append(df_positive,ignore_index=True)
positive

# %%
#other
other=rss_extract("https://www.theguardian.com/uk/lifeandstyle/rss")

# %%
def parse_html_summary(x):
    if type(x)==float:
        return x
    elif x.startswith("<"):
        soup = BeautifulSoup(x, 'html.parser')
        paragraph = soup.p.text
        return paragraph
    else:
        return x

# %%
other['summary'].apply(parse_html_summary)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[242], line 1
# ----> 1 other['summary'].apply(parse_html_summary)
#
# File ~\PycharmProjects\News Filter\.venv\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# ...

# %%
" ".join([i.text for i in BeautifulSoup(other['summary'][0],"html.parser").find_all('p')])
# Out:
# 'As an adult, I was always expecting bad things to happen. These yellowing images reminded me of a time when they had It’s not often we see portraits of our childhood distress. When families brought out cameras in the late 60s, it was usually to capture smiling faces on special occasions, such as Christmas and birthdays. But here I was, 18 months old, in two pages of a yellowing national newspaper, dated January 1969. The first, under the headline “Suffer little children”, showed me in tears as I looked away from the camera into the distance as if I was looking for someone. In the second, I was inconsolable again, looking up and still waiting for a grownup to pick me up and comfort me. That one came with the words: “Be grateful that little girl isn’t yours. She so easily could be!”'

# %%
def get_data(url:str,category:str)->pd.DataFrame:
    #geting data from rss url
    to_add=rss_extract(url)                  
    #clean tags column
    to_add['tags']=to_add['tags'].apply(join_tags)
    #clean summary column contain html syntax
    to_add['summary']=to_add['summary'].apply(parse_html_summary)
    #check duplicate if contain any then remove them
    if to_add.duplicated().sum():
        to_add.drop_duplicates()
    #adding category to dataframe
    to_add['Category']="Natural Disasters"
    #returning rss data into dataframe
    return to_add
